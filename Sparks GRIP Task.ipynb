# %% [markdown]
# ## Prediction using Supervised ML
# - Vinesh Bagara

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset
df = pd.read_csv("spark_Fo_data.txt")
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
# Visualizing data
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.xlabel("Hours", fontsize=14)
plt.ylabel("Scores", fontsize=14)
sns.set_style("darkgrid")

# %% [markdown]
# ## Preparing the data

# %%
# Spliting the data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df["Hours"].values, df["Scores"].values, test_size=0.25, random_state=0)

# %%
# Reshaping the data
X_train = X_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %% [markdown]
# ## Training the Algorithm

# %%
# Applying Linear Regression on training data
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Making predictions

# %%
# printing test hours
X_test
# Out:
# array([[1.5],
#        [3.2],
#        [7.4],
#        [2.5],
#        [5.9],
#        [3.8],
#        [1.9]])

# %%
y_pred = lin_reg.predict(X_test) # predicting values
y_pred  # print predicted values
# Out:
# array([[16.84472176],
#        [33.74557494],
#        [75.50062397],
#        [26.7864001 ],
#        [60.58810646],
#        [39.71058194],
#        [20.8213931 ]])

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import mean_absolute_error

print("mean_absolute_error is {}".format(mean_absolute_error(y_test, y_pred)))
# Out:
# mean_absolute_error is 4.130879918502486

# %% [markdown]
# ## Predicted Score for 9.25 hours of study

# %%
lin_reg.predict([[9.25]])
# Out:
# array([[93.89272889]])
